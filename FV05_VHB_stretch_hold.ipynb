# %% [markdown]
# # Code for 3d large deformation viscoelasticity of elastomeric materials
#
# - Simple tension of a 3D unit cube.
# - Uses quadrature representation of internal variable: viscous deformation tensor Cv.
#
#
# Eric Stewart
#
# ericstew@mit.edu
#
# Spring 2024

# %% [markdown]
# ### Units
# - Basic:
#     - Length: mm
#     - Mass: kg
#     - Time:  s
#     - Mass density: kg/mm^3
#
# - Derived:
#     - Force: mN
#     - Stress: kPa
#     - Energy: uJ
#
# ### Software:
# - Dolfinx v0.8.0

# %% [markdown]
# # Import modules

# %%
# Import FEnicSx/dolfinx
import dolfinx

# For numerical arrays
import numpy as np

# For MPI-based parallelization
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# PETSc solvers
from petsc4py import PETSc

# specific functions from dolfinx modules
from dolfinx import fem, mesh, io, plot, log
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter, XDMFFile


# specific functions from ufl modules
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional ,\
                 gt, dx, inner, derivative, dot, ln, split, exp, eq, cos, acos, ge, le)

# basix finite elements
import basix
from basix.ufl import element, mixed_element, quadrature_element

# Matplotlib for plotting
import matplotlib.pyplot as plt
plt.close('all')

# For timing the code
from datetime import datetime


# Set level of detail for log messages (integer)
# Guide:
# CRITICAL  = 50, // errors that may lead to data corruption
# ERROR     = 40, // things that HAVE gone wrong
# WARNING   = 30, // things that MAY go wrong later
# INFO      = 20, // information of general interest (includes solver info)
# PROGRESS  = 16, // what's happening (broadly)
# TRACE     = 13, // what's happening (in detail)
# DBG       = 10  // sundry
#
log.set_log_level(log.LogLevel.WARNING)

# %% [markdown]
# # Define geometry

# %%
# A 3-D cube
length = 1.0 # mm
domain = mesh.create_box(MPI.COMM_WORLD, [[0.0,0.0,0.0], [length,length,length]],\
                         [1,1,1], mesh.CellType.tetrahedron)

x = ufl.SpatialCoordinate(domain)

# %%
# Identify the planar boundaries of the  box mesh
#
def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], length)
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], length)
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], length)
    
# Mark the sub-domains
boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

# build collections of facets on each subdomain and mark them appropriately.
facet_indices, facet_markers = [], [] # initalize empty collections of indices and markers.
fdim = domain.topology.dim - 1 # geometric dimension of the facet (mesh dimension - 1)
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator) # an array of all the facets in a 
                                                         # given subdomain ("locator")
    facet_indices.append(facets)                         # add these facets to the collection.
    facet_markers.append(np.full_like(facets, marker))   # mark them with the appropriate index.

# Format the facet indices and markers as required for use in dolfinx.
facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
# 
# Add these marked facets as "mesh tags" for later use in BCs.
facet_tags = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %% [markdown]
# **Print out the unique facet index numbers**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain (facets)
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[facet_tags.indices]=facet_tags.values # populating the array with facet tag index numbers
print(np.unique(facet_tags.values))          # printing the unique indices
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# **Visualize reference configuration and boundary facets**

# %%
import pyvista
pyvista.set_jupyter_backend('html')
from dolfinx.plot import vtk_mesh
pyvista.start_xvfb()

# initialize a plotter
plotter = pyvista.Plotter()

# Add the mesh.
topology, cell_types, geometry = plot.vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
plotter.add_mesh(grid, show_edges=True) 
labels = dict(zlabel='Z', xlabel='X', ylabel='Y')
plotter.add_axes(**labels)
    
plotter.screenshot("results/cube_mesh.png")

from IPython.display import Image
Image(filename='results/cube_mesh.png')

# %% [markdown]
# ### Un-comment this cell to see an interactive visualization of the mesh

# %%
# plotter.show()

# %% [markdown]
# ## Define boundary and volume integration measure

# %%
# Define the boundary integration measure "ds" using the facet tags,
# also specify the number of surface quadrature points.
ds = ufl.Measure('ds', domain=domain, subdomain_data=facet_tags, metadata={'quadrature_degree':4})

# Define the volume integration measure "dx" 
# also specify the number of volume quadrature points.
dx = ufl.Measure('dx', domain=domain, metadata={'quadrature_degree': 4})

#  Define facet normal
n = ufl.FacetNormal(domain)

# %% [markdown]
# # Material parameters

# %%
Geq_0   = Constant(domain, 15.36)      # Shear modulus, kPa
Kbulk = Constant(domain, PETSc.ScalarType(1.0e3*Geq_0))            # Bulk modulus, kPa
lambdaL = Constant(domain, 5.85)       # Arruda-Boyce locking stretch

# Viscoelasticity parameters from Wang et al (2016) for VHB4910
#
Gneq_1  = Constant(domain, 26.06)    #  Non-equilibrium shear modulus, kPa
tau_1   = Constant(domain, 0.6074)    #  relaxation time, s
#
Gneq_2  = Constant(domain, 26.53)    #  Non-equilibrium shear modulus, kPa
tau_2   = Constant(domain, 6.56)     #  relaxation time, s
# 
Gneq_3  = Constant(domain, 10.83)    #  Non-equilinrium shear modulus, kPa
tau_3   = Constant(domain, 61.25)    #  relaxation time, s

rho = Constant(domain, 1.0e-6) # Mass density, kg/mm^3

# alpha-method parameters
alpha   = Constant(domain, PETSc.ScalarType(0.0))
gamma   = Constant(domain, PETSc.ScalarType(0.5+alpha))
beta    = Constant(domain, PETSc.ScalarType(0.25*(gamma+0.5)**2))

# %% [markdown]
# # Simulation time-control related params

# %%
# stretch
stretch = 2
# displacement amplitude
uMax = (stretch-1)*length
# Initialize time
t = 0

# input tabular data for time signal
times = np.array([0,    5,  105, 110, 210,  215,  315, 320, 420,  425,  525, 530, 630,  635,  735, 740, 840])
amps  = np.array([0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 1.0, 1.0, 0.75, 0.75, 0.5, 0.5, 0.25, 0.25,   0,   0])

# Total time for stretching signal
Ttot = np.max(times)
# time step size
dt = 0.0005*Ttot
# Create a constant for the time step
dk = Constant(domain, PETSc.ScalarType(dt))

# Function to apply desired displacement signal
def dispRamp(t):
    
    # interpolate the amplitude from the tabular data
    dispAmp = np.interp(t, times, amps)
    
    # multiply the amplitude by uMax.
    disp = uMax*dispAmp
     
    return disp

# %% [markdown]
# # Function spaces

# %%
U2 = element("Lagrange", domain.basix_cell(), 2, shape=(3,))  # For displacement
P1 = element("Lagrange", domain.basix_cell(), 1)  # For pressure
# P0 = element("Lagrange", domain.basix_cell(), 1)
# T0 = element("Lagrange", domain.basix_cell(), 1, shape=(3,3))
P0 = quadrature_element(domain.basix_cell(), degree=2, scheme="default")
# Note: it seems that for the current version of dolfinx, 
# only degree=2 quadrature elements actually function properly 
# in e.g. visualization interpolations and problem solution.
T0 = basix.ufl.blocked_element(P0, shape=(3, 3)) # for Cv
#
TH = mixed_element([U2, P1])     # Taylor-Hood style mixed element
ME = functionspace(domain, TH)    # Total space for all DOFs
#
V1 = functionspace(domain, P0) # Scalar function space.
V2 = functionspace(domain, U2) # Vector function space
V3 = functionspace(domain, T0) # Tensor function space
#
# Define actual functions with the required DOFs
w        = Function(ME)
u, p = split(w)  

# A copy of functions to store values in the previous step
w_old             = Function(ME)
u_old,  p_old = split(w_old)   

# Define test functions        
u_test, p_test = TestFunctions(ME)    

# Define trial functions needed for automatic differentiation
dw = TrialFunction(ME)  

# Define a tensor-valued function for Cv.
Cv_1_old = Function(V3) 
Cv_2_old = Function(V3) 
Cv_3_old = Function(V3) 

# Functions for storing the velocity and acceleration at prev. step
v_old = Function(V2)
a_old = Function(V2)

# Initial conditions: 

# A function for constructing the identity matrix.
#
# To use the interpolate() feature, this must be defined as a 
# function of x.
def identity(x):
    values = np.zeros((domain.geometry.dim*domain.geometry.dim,
                      x.shape[1]), dtype=np.float64)
    values[0] = 1
    values[4] = 1
    values[8] = 1
    return values

# interpolate the identity onto the tensor-valued Cv function.
Cv_1_old.interpolate(identity)  
Cv_2_old.interpolate(identity) 
Cv_3_old.interpolate(identity)

# %% [markdown]
# # Subroutines for kinematics and constitutive equations

# %%
#------------------------------------------------------------- 
# Utility subroutines
#-------------------------------------------------------------
 
# Subroutine for a "safer" sqrt() function which avoids a divide by zero 
# when differentiated. 
def safe_sqrt(x):
    return sqrt(x + 1.0e-16)

# Deformation gradient 
def F_calc(u):
    Id = Identity(3) 
    F = Id + grad(u) 
    return F

#------------------------------------------------------------- 
# Subroutines for computing the viscous flow update
#-------------------------------------------------------------

# Subroutine for computing the viscous stretch Cv at the end of the step.
def Cv_update(u, Cv_old, tau_r):
    
   F = F_calc(u)
   
   J = det(F)
   
   C = F.T*F
   
   fac = 1.0 + (1./3.) * ( dk / tau_r ) * J**(-2./3.) * inner(C, inv(Cv_old) )
   
   Cv_new = ( Cv_old + ( dk / tau_r ) * J**(-2./3.) * C )  / fac
   
   Cv_new_norm = Cv_new / det(Cv_new)**(1/3)
    
   return Cv_new_norm

#------------------------------------------------------------- 
# Subroutines for calculating the equilibrium Cauchy stress
#-------------------------------------------------------------

# Subrountine for computing the effective stretch
def lambdaBar_calc(u):
    
    F = F_calc(u)
    
    J = det(F)
    
    Fbar = J**(-1/3)*F
    
    Cbar = Fbar.T*Fbar
    
    I1 = tr(Cbar)
    
    lambdaBar = safe_sqrt(I1/3.0)
    
    return lambdaBar

# Subroutine for computing the zeta-function in the Arruda-Boyce model.
def zeta_calc(u):
    
    lambdaBar = lambdaBar_calc(u)
    
    # Use Pade approximation of Langevin inverse (A. Cohen, 1991)
    # This is sixth-order accurate.
    z    = lambdaBar/lambdaL
    
    z    = conditional(gt(z,0.99), 0.99, z) # Keep from blowing up
    
    beta = z*(3.0 - z**2.0)/(1.0 - z**2.0)
    
    zeta = (lambdaL/(3*lambdaBar))*beta
    
    return zeta

# Generalized shear modulus for Arruda-Boyce model
def Geq_AB_calc(u):
    
    zeta = zeta_calc(u)
    
    Geq_AB  = Geq_0 * zeta
    
    return Geq_AB

# Subroutine for calculating the  equilibrium Cauchy stress
def T_eq_calc(u,p):
    
    F   = F_calc(u)
    
    J = det(F)
    
    Fbar = J**(-1./3.)*F
    
    Bbar = Fbar*Fbar.T
    
    Geq  = Geq_AB_calc(u)
    
    T_eq = (1/J)* Geq * dev(Bbar) - p * Identity(3)
    
    return T_eq


#------------------------------------------------------------- 
# Subroutine for calculating the total Piola stress
#-------------------------------------------------------------
   
# Subroutine for the non-equilibrium Cauchy stress.
def T_neq_calc(u, Cv, Gneq):
        
    F  = F_calc(u)
    
    J = det(F)
    
    C = F.T*F
    
    T_neq = J**(-5./3.) * Gneq * (F * inv(Cv) * F.T - (1./3.) * inner(C, inv(Cv)) * Identity(3) ) 
    
    return T_neq
    
    
# Subroutine for the total Piola stress.
def  Piola_calc(u, p, Cv_1, Cv_2, Cv_3, Gneq_1, Gneq_2, Gneq_3):
    
    F  = F_calc(u)
    
    J = det(F)
    
    T_eq = T_eq_calc(u,p)
    
    T_neq_1 = T_neq_calc(u, Cv_1, Gneq_1)
    
    T_neq_2 = T_neq_calc(u, Cv_2, Gneq_2)
        
    T_neq_3 = T_neq_calc(u, Cv_3, Gneq_3)
    
    T = T_eq + T_neq_1 + T_neq_2 + T_neq_3
    
    Piola = J * T * inv(F.T)
    
    return Piola 

#---------------------------------------------------------------------
# Subroutine for updating  acceleration using the Newmark beta method:
# a = 1/(2*beta)*((u - u0 - v0*dt)/(0.5*dt*dt) - (1-2*beta)*a0)
#---------------------------------------------------------------------
def update_a(u, u_old, v_old, a_old):
    return (u-u_old-dk*v_old)/beta/dk**2 - (1-2*beta)/2/beta*a_old

#---------------------------------------------------------------------
# Subroutine for updating  velocity using the Newmark beta method
# v = dt * ((1-gamma)*a0 + gamma*a) + v0
#---------------------------------------------------------------------
def update_v(a, u_old, v_old, a_old):
    return v_old + dk*((1-gamma)*a_old + gamma*a)

#---------------------------------------------------------------------
# alpha-method averaging function
#---------------------------------------------------------------------
def avg(x_old, x_new, alpha):
    return alpha*x_old + (1-alpha)*x_new

# %% [markdown]
# # Evaluate kinematics and constitutive relations

# %%
# Get acceleration and velocity at end of step
a_new = update_a(u, u_old, v_old, a_old)
v_new = update_v(a_new, u_old, v_old, a_old)

# get avg (u,p) fields for generalized-alpha method
u_avg  = avg(u_old, u, alpha)
p_avg  = avg(p_old, p, alpha)

# Kinematical quantities
F  = F_calc(u_avg)
J  = det(F)
lambdaBar = lambdaBar_calc(u_avg)

# update the Cv tensors
Cv_1 = Cv_update(u_avg, Cv_1_old, tau_1)
Cv_2 = Cv_update(u_avg, Cv_2_old, tau_2)
Cv_3 = Cv_update(u_avg, Cv_3_old, tau_3)

#  Evaulate the total Piola stress
Piola = Piola_calc(u_avg, p_avg, Cv_1, Cv_2, Cv_3, Gneq_1, Gneq_2, Gneq_3)

# %% [markdown]
# # Weak forms

# %%
# The weak form for the equilibrium equation
#
Res_1  =  inner( Piola, grad(u_test))*dx \
          #+ inner(rho * a_new, u_test)*dx 
          # (we exclude inertial effects for now)
              
# The auxiliary equation for the pressure
#
Res_2 = inner((J-1) + p_avg/Kbulk, p_test)*dx

# The weak form for the viscous strain increment updates

# The total residual
Res = Res_1 + Res_2 

# Automatic differentiation tangent:
a = derivative(Res, w, dw)

# %% [markdown]
# # Set-up output files

# %%
# results file name
results_name = "3D_stretch_hold"

# Function space for projection of results
P1 = element("Lagrange", domain.basix_cell(), 1)
VV1 = fem.functionspace(domain, P1) # linear scalar function space
#
U1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,)) 
VV2 = fem.functionspace(domain, U1) # linear Vector function space
#
T1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,3)) 
VV3 = fem.functionspace(domain, T1) # linear tensor function space

# For visualization purposes, we need to re-project the stress tensor onto a linear function space before 
# we write it (and its components and the von Mises stress, etc) to the VTX file. 
#
# This is because the stress is a complicated "mixed" function of the (quadratic Lagrangian) displacements
# and the (quadrature representation) plastic strain tensor and scalar equivalent plastic strain. 
#
# First, define a function for setting up this kind of projection problem for visualization purposes:
def setup_projection(u, V):

    trial = ufl.TrialFunction(V)
    test  = ufl.TestFunction(V)   

    a = ufl.inner(trial, test)*dx
    L = ufl.inner(u, test)*dx

    projection_problem = dolfinx.fem.petsc.LinearProblem(a, L, [], \
        petsc_options={"ksp_type": "cg", "ksp_rtol": 1e-16, "ksp_atol": 1e-16, "ksp_max_it": 1000})
    
    return projection_problem

# Create a linear problem for projecting the stress tensor onto the linear tensor function space VV3.
#
tensor_projection_problem = setup_projection(Piola, VV3)
Piola_temp = tensor_projection_problem.solve()

# %%
# primary fields to write to output file
u_vis      = Function(VV2, name="disp")
p_vis      = Function(VV1, name="p")

# %%
# Mises stress
T     = Piola_temp*F.T/J
T0    = T - (1/3)*tr(T)*Identity(3)
Mises = sqrt((3/2)*inner(T0, T0))
Mises_vis= Function(VV1,name="Mises")
Mises_expr = Expression(Mises,VV1.element.interpolation_points())

# Cauchy stress components
T11 = Function(VV1)
T11.name = "T11"
T11_expr = Expression(T[0,0],VV1.element.interpolation_points())

T22 = Function(VV1)
T22.name = "T22"
T22_expr = Expression(T[1,1],VV1.element.interpolation_points())

T33 = Function(VV1)
T33.name = "T33"
T33_expr = Expression(T[2,2],VV1.element.interpolation_points())

# %%
# Effective stretch
lambdaBar_vis      = Function(VV1)
lambdaBar_vis.name = "LambdaBar"
lambdaBar_expr     = Expression(lambdaBar, VV1.element.interpolation_points())

# Volumetric deformation
J_vis      = Function(VV1)
J_vis.name = "J"
J_expr     = Expression(J, VV1.element.interpolation_points())

# %%
# set up the output VTX files.
file_results = VTXWriter(
    MPI.COMM_WORLD,
    "results/" + results_name + ".bp",
    [  # put the functions here you wish to write to output
        u_vis, p_vis, # DOF outputs
        Mises_vis, T11, T22, T33, # stress outputs
        lambdaBar_vis, J_vis, # Kinematical outputs
    ],
    engine="BP4",
)

def writeResults(t):
    
    # Update the output fields before writing to VTX.
    #
    u_vis.interpolate(w.sub(0))
    p_vis.interpolate(w.sub(1))
    #
    # re-project to smooth visualization of quadrature functions
    # before interpolating.
    Piola_temp = tensor_projection_problem.solve()
    Mises_vis.interpolate(Mises_expr)
    T11.interpolate(T11_expr)
    T22.interpolate(T22_expr)
    T33.interpolate(T33_expr)
    #
    lambdaBar_vis.interpolate(lambdaBar_expr)
    J_vis.interpolate(J_expr)
       
    # Finally, write output fields to VTX.
    #
    file_results.write(t)

# %% [markdown]
# # Infrastructure for pulling out time history data (force, displacement, etc.)

# %%
# computing the reaction force using the stress field
traction = dot(Piola_temp, n)
Force    = dot(traction, n)*ds(4)
rxnForce = fem.form(Force)

# %%
# # infrastructure for evaluating functions at a certain point efficiently
# pointForEval = np.array([length, length, length])
# bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
# cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForEval)
# colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForEval).array

# %% [markdown]
# ## Boundary condtions

# %%
# Constant for applied displacement
disp_cons = Constant(domain,PETSc.ScalarType(dispRamp(0)))

# Find the specific DOFs which will be constrained.
xBot_u1_dofs = fem.locate_dofs_topological(ME.sub(0).sub(0), facet_tags.dim, facet_tags.find(1))
yBot_u2_dofs = fem.locate_dofs_topological(ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(3))
zBot_u3_dofs = fem.locate_dofs_topological(ME.sub(0).sub(2), facet_tags.dim, facet_tags.find(5))
yTop_u2_dofs = fem.locate_dofs_topological(ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(4))

# building Dirichlet BCs
bcs_1 = dirichletbc(0.0, xBot_u1_dofs, ME.sub(0).sub(0))  # u1 fix - xBot
bcs_2 = dirichletbc(0.0, yBot_u2_dofs, ME.sub(0).sub(1))  # u2 fix - yBot
bcs_3 = dirichletbc(0.0, zBot_u3_dofs, ME.sub(0).sub(2))  # u3 fix - zBot
#
bcs_4 = dirichletbc(disp_cons, yTop_u2_dofs, ME.sub(0).sub(1))  # disp ramp - yTop

bcs = [bcs_1, bcs_2, bcs_3, bcs_4]

# %% [markdown]
# ## Define the nonlinear variational problem

# %%
# Set up nonlinear problem
problem = NonlinearProblem(Res, w, bcs, a)

# the global newton solver and params
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 50
solver.report = True

#  The Krylov solver parameters.
ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly" # "preonly" works equally well
opts[f"{option_prefix}pc_type"] = "lu" # do not use 'gamg' pre-conditioner
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
opts[f"{option_prefix}ksp_max_it"] = 30
ksp.setFromOptions()

# %% [markdown]
# ##  Start calculation loop

# %%
# Give the step a descriptive name
step = "Tension"

# Variables for storing time history
totSteps = 1000000
timeHist0 = np.zeros(shape=[totSteps])
timeHist1 = np.zeros(shape=[totSteps]) 
timeHist2 = np.zeros(shape=[totSteps]) 

#Iinitialize a counter for reporting data
ii=0

#  Set up temporary "helper" functions and expressions 
#  for updating the internal variables.
#
# For the Cv tensors:
Cv_1_temp = Function(V3)
Cv_1_expr = Expression(Cv_1, V3.element.interpolation_points())
#
Cv_2_temp = Function(V3)
Cv_2_expr = Expression(Cv_2, V3.element.interpolation_points())
#
Cv_3_temp = Function(V3)
Cv_3_expr = Expression(Cv_3, V3.element.interpolation_points())
#
# and also for the velocity and acceleration.
v_temp = Function(V2)
a_temp = Function(V2)
#
v_expr = Expression(v_new,V2.element.interpolation_points())
a_expr = Expression(a_new,V2.element.interpolation_points())

# Write initial state to file
writeResults(t=0.0)    

# print a message for simulation startup
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")
# Store start time 
startTime = datetime.now()

# Time-stepping solution procedure loop
while (round(t + dt, 9) <= Ttot):
     
    # increment time
    t += dt 
    
    # increment counter
    ii += 1
    
    # update time variables in time-dependent BCs 
    disp_cons.value = dispRamp(t)
    
    # Solve the problem
    (iter, converged) = solver.solve(w)
    
    # Collect results from MPI ghost processes
    w.x.scatter_forward()

    # Print progress of calculation periodically
    if ii%5 == 0:      
      now = datetime.now()
      current_time = now.strftime("%H:%M:%S")
      print("Step: {} |   Increment: {} | Iterations: {}".format(step, ii, iter))
      print("dt: {} s | Simulation Time: {} s  of  {} s".format(round(dt, 4), round(t,4), Ttot))
      print()   
      
    # Write output to file
    writeResults(t)
       
    # Store time history variables at this time  
    timeHist0[ii] = t # current time 
    #
    timeHist1[ii] = dispRamp(t) # time history of displacement
    #
    timeHist2[ii] = domain.comm.gather(fem.assemble_scalar(rxnForce))[0] # time history of engineering stress
    
    # update internal variables 
    #
    # interpolate the values of the internal variables into their "temp" functions
    Cv_1_temp.interpolate(Cv_1_expr)
    Cv_2_temp.interpolate(Cv_2_expr)
    Cv_3_temp.interpolate(Cv_3_expr)
    #
    v_temp.interpolate(v_expr)
    a_temp.interpolate(a_expr)

    # Update DOFs for next step
    w_old.x.array[:] = w.x.array
    
    # update the old values of internal variables for next step
    Cv_1_old.x.array[:] = Cv_1_temp.x.array[:]
    Cv_2_old.x.array[:] = Cv_2_temp.x.array[:]
    Cv_3_old.x.array[:] = Cv_3_temp.x.array[:]
    #
    v_old.x.array[:] = v_temp.x.array[:]
    a_old.x.array[:] = a_temp.x.array[:]
    
# close the output file.
file_results.close()
         
# End analysis
print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Tension |   Increment: 5 | Iterations: 4
# dt: 0.42 s | Simulation Time: 2.1 s  of  840 s
#
# Step: Tension |   Increment: 10 | Iterations: 4
# dt: 0.42 s | Simulation Time: 4.2 s  of  840 s
# Step: Tension |   Increment: 15 | Iterations: 3
# dt: 0.42 s | Simulation Time: 6.3 s  of  840 s
#
# Step: Tension |   Increment: 20 | Iterations: 3
# dt: 0.42 s | Simulation Time: 8.4 s  of  840 s
#
# Step: Tension |   Increment: 25 | Iterations: 3
# dt: 0.42 s | Simulation Time: 10.5 s  of  840 s
#
# Step: Tension |   Increment: 30 | Iterations: 3
# dt: 0.42 s | Simulation Time: 12.6 s  of  840 s
#
# Step: Tension |   Increment: 35 | Iterations: 3
# dt: 0.42 s | Simulation Time: 14.7 s  of  840 s
#
# Step: Tension |   Increment: 40 | Iterations: 3
# dt: 0.42 s | Simulation Time: 16.8 s  of  840 s
#
# Step: Tension |   Increment: 45 | Iterations: 3
# dt: 0.42 s | Simulation Time: 18.9 s  of  840 s
#
# Step: Tension |   Increment: 50 | Iterations: 3
# dt: 0.42 s | Simulation Time: 21.0 s  of  840 s
#
# Step: Tension |   Increment: 55 | Iterations: 3
# dt: 0.42 s | Simulation Time: 23.1 s  of  840 s
#
# Step: Tension |   Increment: 60 | Iterations: 3
# dt: 0.42 s | Simulation Time: 25.2 s  of  840 s
#
# Step: Tension |   Increment: 65 | Iterations: 3
# dt: 0.42 s | Simulation Time: 27.3 s  of  840 s
#
# Step: Tension |   Increment: 70 | Iterations: 3
# dt: 0.42 s | Simulation Time: 29.4 s  of  840 s
#
# Step: Tension |   Increment: 75 | Iterations: 3
# dt: 0.42 s | Simulation Time: 31.5 s  of  840 s
#
# Step: Tension |   Increment: 80 | Iterations: 3
# dt: 0.42 s | Simulation Time: 33.6 s  of  840 s
#
# Step: Tension |   Increment: 85 | Iterations: 3
# dt: 0.42 s | Simulation Time: 35.7 s  of  840 s
#
# Step: Tension |   Increment: 90 | Iterations: 3
# dt: 0.42 s | Simulation Time: 37.8 s  of  840 s
#
# Step: Tension |   Increment: 95 | Iterations: 3
# dt: 0.42 s | Simulation Time: 39.9 s  of  840 s
#
# Step: Tension |   Increment: 100 | Iterations: 3
# dt: 0.42 s | Simulation Time: 42.0 s  of  840 s
#
# Step: Tension |   Increment: 105 | Iterations: 2
# dt: 0.42 s | Simulation Time: 44.1 s  of  840 s
#
# Step: Tension |   Increment: 110 | Iterations: 2
# dt: 0.42 s | Simulation Time: 46.2 s  of  840 s
#
# Step: Tension |   Increment: 115 | Iterations: 2
# dt: 0.42 s | Simulation Time: 48.3 s  of  840 s
#
# Step: Tension |   Increment: 120 | Iterations: 2
# dt: 0.42 s | Simulation Time: 50.4 s  of  840 s
#
# Step: Tension |   Increment: 125 | Iterations: 2
# dt: 0.42 s | Simulation Time: 52.5 s  of  840 s
#
# Step: Tension |   Increment: 130 | Iterations: 2
# dt: 0.42 s | Simulation Time: 54.6 s  of  840 s
#
# Step: Tension |   Increment: 135 | Iterations: 2
# dt: 0.42 s | Simulation Time: 56.7 s  of  840 s
#
# Step: Tension |   Increment: 140 | Iterations: 2
# dt: 0.42 s | Simulation Time: 58.8 s  of  840 s
#
# Step: Tension |   Increment: 145 | Iterations: 2
# dt: 0.42 s | Simulation Time: 60.9 s  of  840 s
#
# Step: Tension |   Increment: 150 | Iterations: 2
# dt: 0.42 s | Simulation Time: 63.0 s  of  840 s
#
# Step: Tension |   Increment: 155 | Iterations: 2
# dt: 0.42 s | Simulation Time: 65.1 s  of  840 s
#
# Step: Tension |   Increment: 160 | Iterations: 2
# dt: 0.42 s | Simulation Time: 67.2 s  of  840 s
#
# Step: Tension |   Increment: 165 | Iterations: 2
# dt: 0.42 s | Simulation Time: 69.3 s  of  840 s
#
# Step: Tension |   Increment: 170 | Iterations: 2
# dt: 0.42 s | Simulation Time: 71.4 s  of  840 s
#
# Step: Tension |   Increment: 175 | Iterations: 2
# dt: 0.42 s | Simulation Time: 73.5 s  of  840 s
#
# Step: Tension |   Increment: 180 | Iterations: 2
# dt: 0.42 s | Simulation Time: 75.6 s  of  840 s
#
# Step: Tension |   Increment: 185 | Iterations: 2
# dt: 0.42 s | Simulation Time: 77.7 s  of  840 s
#
# Step: Tension |   Increment: 190 | Iterations: 2
# dt: 0.42 s | Simulation Time: 79.8 s  of  840 s
#
# Step: Tension |   Increment: 195 | Iterations: 2
# dt: 0.42 s | Simulation Time: 81.9 s  of  840 s
#
# Step: Tension |   Increment: 200 | Iterations: 2
# dt: 0.42 s | Simulation Time: 84.0 s  of  840 s
#
# Step: Tension |   Increment: 205 | Iterations: 2
# dt: 0.42 s | Simulation Time: 86.1 s  of  840 s
#
# Step: Tension |   Increment: 210 | Iterations: 2
# dt: 0.42 s | Simulation Time: 88.2 s  of  840 s
#
# Step: Tension |   Increment: 215 | Iterations: 2
# dt: 0.42 s | Simulation Time: 90.3 s  of  840 s
#
# Step: Tension |   Increment: 220 | Iterations: 2
# dt: 0.42 s | Simulation Time: 92.4 s  of  840 s
#
# Step: Tension |   Increment: 225 | Iterations: 2
# dt: 0.42 s | Simulation Time: 94.5 s  of  840 s
#
# Step: Tension |   Increment: 230 | Iterations: 2
# dt: 0.42 s | Simulation Time: 96.6 s  of  840 s
#
# Step: Tension |   Increment: 235 | Iterations: 2
# dt: 0.42 s | Simulation Time: 98.7 s  of  840 s
#
# Step: Tension |   Increment: 240 | Iterations: 2
# dt: 0.42 s | Simulation Time: 100.8 s  of  840 s
#
# Step: Tension |   Increment: 245 | Iterations: 2
# dt: 0.42 s | Simulation Time: 102.9 s  of  840 s
#
# Step: Tension |   Increment: 250 | Iterations: 2
# dt: 0.42 s | Simulation Time: 105.0 s  of  840 s
#
# Step: Tension |   Increment: 255 | Iterations: 4
# dt: 0.42 s | Simulation Time: 107.1 s  of  840 s
#
# Step: Tension |   Increment: 260 | Iterations: 4
# dt: 0.42 s | Simulation Time: 109.2 s  of  840 s
#
# Step: Tension |   Increment: 265 | Iterations: 3
# dt: 0.42 s | Simulation Time: 111.3 s  of  840 s
#
# Step: Tension |   Increment: 270 | Iterations: 3
# dt: 0.42 s | Simulation Time: 113.4 s  of  840 s
#
# Step: Tension |   Increment: 275 | Iterations: 3
# dt: 0.42 s | Simulation Time: 115.5 s  of  840 s
#
# Step: Tension |   Increment: 280 | Iterations: 3
# dt: 0.42 s | Simulation Time: 117.6 s  of  840 s
#
# Step: Tension |   Increment: 285 | Iterations: 3
# dt: 0.42 s | Simulation Time: 119.7 s  of  840 s
#
# Step: Tension |   Increment: 290 | Iterations: 3
# dt: 0.42 s | Simulation Time: 121.8 s  of  840 s
#
# Step: Tension |   Increment: 295 | Iterations: 3
# dt: 0.42 s | Simulation Time: 123.9 s  of  840 s
#
# Step: Tension |   Increment: 300 | Iterations: 3
# dt: 0.42 s | Simulation Time: 126.0 s  of  840 s
#
# Step: Tension |   Increment: 305 | Iterations: 3
# dt: 0.42 s | Simulation Time: 128.1 s  of  840 s
#
# Step: Tension |   Increment: 310 | Iterations: 3
# dt: 0.42 s | Simulation Time: 130.2 s  of  840 s
#
# Step: Tension |   Increment: 315 | Iterations: 3
# dt: 0.42 s | Simulation Time: 132.3 s  of  840 s
#
# Step: Tension |   Increment: 320 | Iterations: 3
# dt: 0.42 s | Simulation Time: 134.4 s  of  840 s
#
# Step: Tension |   Increment: 325 | Iterations: 3
# dt: 0.42 s | Simulation Time: 136.5 s  of  840 s
#
# Step: Tension |   Increment: 330 | Iterations: 3
# dt: 0.42 s | Simulation Time: 138.6 s  of  840 s
#
# Step: Tension |   Increment: 335 | Iterations: 3
# dt: 0.42 s | Simulation Time: 140.7 s  of  840 s
#
# Step: Tension |   Increment: 340 | Iterations: 3
# dt: 0.42 s | Simulation Time: 142.8 s  of  840 s
#
# Step: Tension |   Increment: 345 | Iterations: 3
# dt: 0.42 s | Simulation Time: 144.9 s  of  840 s
#
# Step: Tension |   Increment: 350 | Iterations: 2
# dt: 0.42 s | Simulation Time: 147.0 s  of  840 s
#
# Step: Tension |   Increment: 355 | Iterations: 2
# dt: 0.42 s | Simulation Time: 149.1 s  of  840 s
#
# Step: Tension |   Increment: 360 | Iterations: 2
# dt: 0.42 s | Simulation Time: 151.2 s  of  840 s
#
# Step: Tension |   Increment: 365 | Iterations: 2
# dt: 0.42 s | Simulation Time: 153.3 s  of  840 s
#
# Step: Tension |   Increment: 370 | Iterations: 2
# dt: 0.42 s | Simulation Time: 155.4 s  of  840 s
#
# Step: Tension |   Increment: 375 | Iterations: 2
# dt: 0.42 s | Simulation Time: 157.5 s  of  840 s
#
# Step: Tension |   Increment: 380 | Iterations: 2
# dt: 0.42 s | Simulation Time: 159.6 s  of  840 s
#
# Step: Tension |   Increment: 385 | Iterations: 2
# dt: 0.42 s | Simulation Time: 161.7 s  of  840 s
#
# Step: Tension |   Increment: 390 | Iterations: 2
# dt: 0.42 s | Simulation Time: 163.8 s  of  840 s
#
# Step: Tension |   Increment: 395 | Iterations: 2
# dt: 0.42 s | Simulation Time: 165.9 s  of  840 s
#
# Step: Tension |   Increment: 400 | Iterations: 2
# dt: 0.42 s | Simulation Time: 168.0 s  of  840 s
#
# Step: Tension |   Increment: 405 | Iterations: 2
# dt: 0.42 s | Simulation Time: 170.1 s  of  840 s
#
# Step: Tension |   Increment: 410 | Iterations: 2
# dt: 0.42 s | Simulation Time: 172.2 s  of  840 s
#
# Step: Tension |   Increment: 415 | Iterations: 2
# dt: 0.42 s | Simulation Time: 174.3 s  of  840 s
#
# Step: Tension |   Increment: 420 | Iterations: 2
# dt: 0.42 s | Simulation Time: 176.4 s  of  840 s
#
# Step: Tension |   Increment: 425 | Iterations: 2
# dt: 0.42 s | Simulation Time: 178.5 s  of  840 s
#
# Step: Tension |   Increment: 430 | Iterations: 2
# dt: 0.42 s | Simulation Time: 180.6 s  of  840 s
#
# Step: Tension |   Increment: 435 | Iterations: 2
# dt: 0.42 s | Simulation Time: 182.7 s  of  840 s
#
# Step: Tension |   Increment: 440 | Iterations: 2
# dt: 0.42 s | Simulation Time: 184.8 s  of  840 s
#
# Step: Tension |   Increment: 445 | Iterations: 2
# dt: 0.42 s | Simulation Time: 186.9 s  of  840 s
#
# Step: Tension |   Increment: 450 | Iterations: 2
# dt: 0.42 s | Simulation Time: 189.0 s  of  840 s
#
# Step: Tension |   Increment: 455 | Iterations: 2
# dt: 0.42 s | Simulation Time: 191.1 s  of  840 s
#
# Step: Tension |   Increment: 460 | Iterations: 2
# dt: 0.42 s | Simulation Time: 193.2 s  of  840 s
#
# Step: Tension |   Increment: 465 | Iterations: 2
# dt: 0.42 s | Simulation Time: 195.3 s  of  840 s
#
# Step: Tension |   Increment: 470 | Iterations: 2
# dt: 0.42 s | Simulation Time: 197.4 s  of  840 s
#
# Step: Tension |   Increment: 475 | Iterations: 2
# dt: 0.42 s | Simulation Time: 199.5 s  of  840 s
#
# Step: Tension |   Increment: 480 | Iterations: 2
# dt: 0.42 s | Simulation Time: 201.6 s  of  840 s
#
# Step: Tension |   Increment: 485 | Iterations: 2
# dt: 0.42 s | Simulation Time: 203.7 s  of  840 s
#
# Step: Tension |   Increment: 490 | Iterations: 2
# dt: 0.42 s | Simulation Time: 205.8 s  of  840 s
#
# Step: Tension |   Increment: 495 | Iterations: 2
# dt: 0.42 s | Simulation Time: 207.9 s  of  840 s
#
# Step: Tension |   Increment: 500 | Iterations: 2
# dt: 0.42 s | Simulation Time: 210.0 s  of  840 s
#
# Step: Tension |   Increment: 505 | Iterations: 4
# dt: 0.42 s | Simulation Time: 212.1 s  of  840 s
#
# Step: Tension |   Increment: 510 | Iterations: 4
# dt: 0.42 s | Simulation Time: 214.2 s  of  840 s
#
# Step: Tension |   Increment: 515 | Iterations: 3
# dt: 0.42 s | Simulation Time: 216.3 s  of  840 s
#
# Step: Tension |   Increment: 520 | Iterations: 3
# dt: 0.42 s | Simulation Time: 218.4 s  of  840 s
#
# Step: Tension |   Increment: 525 | Iterations: 3
# dt: 0.42 s | Simulation Time: 220.5 s  of  840 s
#
# Step: Tension |   Increment: 530 | Iterations: 3
# dt: 0.42 s | Simulation Time: 222.6 s  of  840 s
#
# Step: Tension |   Increment: 535 | Iterations: 3
# dt: 0.42 s | Simulation Time: 224.7 s  of  840 s
#
# Step: Tension |   Increment: 540 | Iterations: 3
# dt: 0.42 s | Simulation Time: 226.8 s  of  840 s
#
# Step: Tension |   Increment: 545 | Iterations: 3
# dt: 0.42 s | Simulation Time: 228.9 s  of  840 s
#
# Step: Tension |   Increment: 550 | Iterations: 3
# dt: 0.42 s | Simulation Time: 231.0 s  of  840 s
#
# Step: Tension |   Increment: 555 | Iterations: 3
# dt: 0.42 s | Simulation Time: 233.1 s  of  840 s
#
# Step: Tension |   Increment: 560 | Iterations: 3
# dt: 0.42 s | Simulation Time: 235.2 s  of  840 s
#
# Step: Tension |   Increment: 565 | Iterations: 3
# dt: 0.42 s | Simulation Time: 237.3 s  of  840 s
#
# Step: Tension |   Increment: 570 | Iterations: 3
# dt: 0.42 s | Simulation Time: 239.4 s  of  840 s
#
# Step: Tension |   Increment: 575 | Iterations: 3
# dt: 0.42 s | Simulation Time: 241.5 s  of  840 s
#
# Step: Tension |   Increment: 580 | Iterations: 3
# dt: 0.42 s | Simulation Time: 243.6 s  of  840 s
#
# Step: Tension |   Increment: 585 | Iterations: 3
# dt: 0.42 s | Simulation Time: 245.7 s  of  840 s
#
# Step: Tension |   Increment: 590 | Iterations: 2
# dt: 0.42 s | Simulation Time: 247.8 s  of  840 s
#
# Step: Tension |   Increment: 595 | Iterations: 2
# dt: 0.42 s | Simulation Time: 249.9 s  of  840 s
#
# Step: Tension |   Increment: 600 | Iterations: 2
# dt: 0.42 s | Simulation Time: 252.0 s  of  840 s
#
# Step: Tension |   Increment: 605 | Iterations: 2
# dt: 0.42 s | Simulation Time: 254.1 s  of  840 s
#
# Step: Tension |   Increment: 610 | Iterations: 2
# dt: 0.42 s | Simulation Time: 256.2 s  of  840 s
#
# Step: Tension |   Increment: 615 | Iterations: 2
# dt: 0.42 s | Simulation Time: 258.3 s  of  840 s
#
# Step: Tension |   Increment: 620 | Iterations: 2
# dt: 0.42 s | Simulation Time: 260.4 s  of  840 s
#
# Step: Tension |   Increment: 625 | Iterations: 2
# dt: 0.42 s | Simulation Time: 262.5 s  of  840 s
#
# Step: Tension |   Increment: 630 | Iterations: 2
# dt: 0.42 s | Simulation Time: 264.6 s  of  840 s
#
# Step: Tension |   Increment: 635 | Iterations: 2
# dt: 0.42 s | Simulation Time: 266.7 s  of  840 s
#
# Step: Tension |   Increment: 640 | Iterations: 2
# dt: 0.42 s | Simulation Time: 268.8 s  of  840 s
#
# Step: Tension |   Increment: 645 | Iterations: 2
# dt: 0.42 s | Simulation Time: 270.9 s  of  840 s
#
# Step: Tension |   Increment: 650 | Iterations: 2
# dt: 0.42 s | Simulation Time: 273.0 s  of  840 s
#
# Step: Tension |   Increment: 655 | Iterations: 2
# dt: 0.42 s | Simulation Time: 275.1 s  of  840 s
#
# Step: Tension |   Increment: 660 | Iterations: 2
# dt: 0.42 s | Simulation Time: 277.2 s  of  840 s
#
# Step: Tension |   Increment: 665 | Iterations: 2
# dt: 0.42 s | Simulation Time: 279.3 s  of  840 s
#
# Step: Tension |   Increment: 670 | Iterations: 2
# dt: 0.42 s | Simulation Time: 281.4 s  of  840 s
#
# Step: Tension |   Increment: 675 | Iterations: 2
# dt: 0.42 s | Simulation Time: 283.5 s  of  840 s
#
# Step: Tension |   Increment: 680 | Iterations: 2
# dt: 0.42 s | Simulation Time: 285.6 s  of  840 s
#
# Step: Tension |   Increment: 685 | Iterations: 2
# dt: 0.42 s | Simulation Time: 287.7 s  of  840 s
#
# Step: Tension |   Increment: 690 | Iterations: 2
# dt: 0.42 s | Simulation Time: 289.8 s  of  840 s
#
# Step: Tension |   Increment: 695 | Iterations: 2
# dt: 0.42 s | Simulation Time: 291.9 s  of  840 s
#
# Step: Tension |   Increment: 700 | Iterations: 2
# dt: 0.42 s | Simulation Time: 294.0 s  of  840 s
#
# Step: Tension |   Increment: 705 | Iterations: 2
# dt: 0.42 s | Simulation Time: 296.1 s  of  840 s
#
# Step: Tension |   Increment: 710 | Iterations: 2
# dt: 0.42 s | Simulation Time: 298.2 s  of  840 s
#
# Step: Tension |   Increment: 715 | Iterations: 2
# dt: 0.42 s | Simulation Time: 300.3 s  of  840 s
#
# Step: Tension |   Increment: 720 | Iterations: 2
# dt: 0.42 s | Simulation Time: 302.4 s  of  840 s
#
# Step: Tension |   Increment: 725 | Iterations: 2
# dt: 0.42 s | Simulation Time: 304.5 s  of  840 s
#
# Step: Tension |   Increment: 730 | Iterations: 2
# dt: 0.42 s | Simulation Time: 306.6 s  of  840 s
#
# Step: Tension |   Increment: 735 | Iterations: 2
# dt: 0.42 s | Simulation Time: 308.7 s  of  840 s
#
# Step: Tension |   Increment: 740 | Iterations: 2
# dt: 0.42 s | Simulation Time: 310.8 s  of  840 s
#
# Step: Tension |   Increment: 745 | Iterations: 2
# dt: 0.42 s | Simulation Time: 312.9 s  of  840 s
#
# Step: Tension |   Increment: 750 | Iterations: 2
# dt: 0.42 s | Simulation Time: 315.0 s  of  840 s
#
# Step: Tension |   Increment: 755 | Iterations: 4
# dt: 0.42 s | Simulation Time: 317.1 s  of  840 s
#
# Step: Tension |   Increment: 760 | Iterations: 4
# dt: 0.42 s | Simulation Time: 319.2 s  of  840 s
#
# Step: Tension |   Increment: 765 | Iterations: 3
# dt: 0.42 s | Simulation Time: 321.3 s  of  840 s
#
# Step: Tension |   Increment: 770 | Iterations: 3
# dt: 0.42 s | Simulation Time: 323.4 s  of  840 s
#
# Step: Tension |   Increment: 775 | Iterations: 3
# dt: 0.42 s | Simulation Time: 325.5 s  of  840 s
#
# Step: Tension |   Increment: 780 | Iterations: 3
# dt: 0.42 s | Simulation Time: 327.6 s  of  840 s
#
# Step: Tension |   Increment: 785 | Iterations: 3
# dt: 0.42 s | Simulation Time: 329.7 s  of  840 s
#
# Step: Tension |   Increment: 790 | Iterations: 3
# dt: 0.42 s | Simulation Time: 331.8 s  of  840 s
#
# Step: Tension |   Increment: 795 | Iterations: 3
# dt: 0.42 s | Simulation Time: 333.9 s  of  840 s
#
# Step: Tension |   Increment: 800 | Iterations: 3
# dt: 0.42 s | Simulation Time: 336.0 s  of  840 s
#
# Step: Tension |   Increment: 805 | Iterations: 3
# dt: 0.42 s | Simulation Time: 338.1 s  of  840 s
#
# Step: Tension |   Increment: 810 | Iterations: 3
# dt: 0.42 s | Simulation Time: 340.2 s  of  840 s
#
# Step: Tension |   Increment: 815 | Iterations: 3
# dt: 0.42 s | Simulation Time: 342.3 s  of  840 s
#
# Step: Tension |   Increment: 820 | Iterations: 3
# dt: 0.42 s | Simulation Time: 344.4 s  of  840 s
#
# Step: Tension |   Increment: 825 | Iterations: 3
# dt: 0.42 s | Simulation Time: 346.5 s  of  840 s
#
# Step: Tension |   Increment: 830 | Iterations: 2
# dt: 0.42 s | Simulation Time: 348.6 s  of  840 s
#
# Step: Tension |   Increment: 835 | Iterations: 2
# dt: 0.42 s | Simulation Time: 350.7 s  of  840 s
#
# Step: Tension |   Increment: 840 | Iterations: 2
# dt: 0.42 s | Simulation Time: 352.8 s  of  840 s
#
# Step: Tension |   Increment: 845 | Iterations: 2
# dt: 0.42 s | Simulation Time: 354.9 s  of  840 s
#
# Step: Tension |   Increment: 850 | Iterations: 2
# dt: 0.42 s | Simulation Time: 357.0 s  of  840 s
#
# Step: Tension |   Increment: 855 | Iterations: 2
# dt: 0.42 s | Simulation Time: 359.1 s  of  840 s
#
# Step: Tension |   Increment: 860 | Iterations: 2
# dt: 0.42 s | Simulation Time: 361.2 s  of  840 s
#
# Step: Tension |   Increment: 865 | Iterations: 2
# dt: 0.42 s | Simulation Time: 363.3 s  of  840 s
#
# Step: Tension |   Increment: 870 | Iterations: 2
# dt: 0.42 s | Simulation Time: 365.4 s  of  840 s
#
# Step: Tension |   Increment: 875 | Iterations: 2
# dt: 0.42 s | Simulation Time: 367.5 s  of  840 s
#
# Step: Tension |   Increment: 880 | Iterations: 2
# dt: 0.42 s | Simulation Time: 369.6 s  of  840 s
#
# Step: Tension |   Increment: 885 | Iterations: 2
# dt: 0.42 s | Simulation Time: 371.7 s  of  840 s
#
# Step: Tension |   Increment: 890 | Iterations: 2
# dt: 0.42 s | Simulation Time: 373.8 s  of  840 s
#
# Step: Tension |   Increment: 895 | Iterations: 2
# dt: 0.42 s | Simulation Time: 375.9 s  of  840 s
#
# Step: Tension |   Increment: 900 | Iterations: 2
# dt: 0.42 s | Simulation Time: 378.0 s  of  840 s
#
# Step: Tension |   Increment: 905 | Iterations: 2
# dt: 0.42 s | Simulation Time: 380.1 s  of  840 s
#
# Step: Tension |   Increment: 910 | Iterations: 2
# dt: 0.42 s | Simulation Time: 382.2 s  of  840 s
#
# Step: Tension |   Increment: 915 | Iterations: 2
# dt: 0.42 s | Simulation Time: 384.3 s  of  840 s
#
# Step: Tension |   Increment: 920 | Iterations: 2
# dt: 0.42 s | Simulation Time: 386.4 s  of  840 s
#
# Step: Tension |   Increment: 925 | Iterations: 2
# dt: 0.42 s | Simulation Time: 388.5 s  of  840 s
#
# Step: Tension |   Increment: 930 | Iterations: 2
# dt: 0.42 s | Simulation Time: 390.6 s  of  840 s
#
# Step: Tension |   Increment: 935 | Iterations: 2
# dt: 0.42 s | Simulation Time: 392.7 s  of  840 s
#
# Step: Tension |   Increment: 940 | Iterations: 2
# dt: 0.42 s | Simulation Time: 394.8 s  of  840 s
#
# Step: Tension |   Increment: 945 | Iterations: 2
# dt: 0.42 s | Simulation Time: 396.9 s  of  840 s
#
# Step: Tension |   Increment: 950 | Iterations: 2
# dt: 0.42 s | Simulation Time: 399.0 s  of  840 s
#
# Step: Tension |   Increment: 955 | Iterations: 2
# dt: 0.42 s | Simulation Time: 401.1 s  of  840 s
#
# Step: Tension |   Increment: 960 | Iterations: 2
# dt: 0.42 s | Simulation Time: 403.2 s  of  840 s
#
# Step: Tension |   Increment: 965 | Iterations: 2
# dt: 0.42 s | Simulation Time: 405.3 s  of  840 s
#
# Step: Tension |   Increment: 970 | Iterations: 2
# dt: 0.42 s | Simulation Time: 407.4 s  of  840 s
#
# Step: Tension |   Increment: 975 | Iterations: 2
# dt: 0.42 s | Simulation Time: 409.5 s  of  840 s
#
# Step: Tension |   Increment: 980 | Iterations: 2
# dt: 0.42 s | Simulation Time: 411.6 s  of  840 s
#
# Step: Tension |   Increment: 985 | Iterations: 2
# dt: 0.42 s | Simulation Time: 413.7 s  of  840 s
#
# Step: Tension |   Increment: 990 | Iterations: 2
# dt: 0.42 s | Simulation Time: 415.8 s  of  840 s
#
# Step: Tension |   Increment: 995 | Iterations: 2
# dt: 0.42 s | Simulation Time: 417.9 s  of  840 s
#
# Step: Tension |   Increment: 1000 | Iterations: 2
# dt: 0.42 s | Simulation Time: 420.0 s  of  840 s
#
# Step: Tension |   Increment: 1005 | Iterations: 4
# dt: 0.42 s | Simulation Time: 422.1 s  of  840 s
#
# Step: Tension |   Increment: 1010 | Iterations: 4
# dt: 0.42 s | Simulation Time: 424.2 s  of  840 s
#
# Step: Tension |   Increment: 1015 | Iterations: 3
# dt: 0.42 s | Simulation Time: 426.3 s  of  840 s
#
# Step: Tension |   Increment: 1020 | Iterations: 3
# dt: 0.42 s | Simulation Time: 428.4 s  of  840 s
#
# Step: Tension |   Increment: 1025 | Iterations: 3
# dt: 0.42 s | Simulation Time: 430.5 s  of  840 s
#
# Step: Tension |   Increment: 1030 | Iterations: 3
# dt: 0.42 s | Simulation Time: 432.6 s  of  840 s
#
# Step: Tension |   Increment: 1035 | Iterations: 3
# dt: 0.42 s | Simulation Time: 434.7 s  of  840 s
#
# Step: Tension |   Increment: 1040 | Iterations: 3
# dt: 0.42 s | Simulation Time: 436.8 s  of  840 s
#
# Step: Tension |   Increment: 1045 | Iterations: 3
# dt: 0.42 s | Simulation Time: 438.9 s  of  840 s
#
# Step: Tension |   Increment: 1050 | Iterations: 3
# dt: 0.42 s | Simulation Time: 441.0 s  of  840 s
#
# Step: Tension |   Increment: 1055 | Iterations: 3
# dt: 0.42 s | Simulation Time: 443.1 s  of  840 s
#
# Step: Tension |   Increment: 1060 | Iterations: 3
# dt: 0.42 s | Simulation Time: 445.2 s  of  840 s
#
# Step: Tension |   Increment: 1065 | Iterations: 3
# dt: 0.42 s | Simulation Time: 447.3 s  of  840 s
#
# Step: Tension |   Increment: 1070 | Iterations: 2
# dt: 0.42 s | Simulation Time: 449.4 s  of  840 s
#
# Step: Tension |   Increment: 1075 | Iterations: 2
# dt: 0.42 s | Simulation Time: 451.5 s  of  840 s
#
# Step: Tension |   Increment: 1080 | Iterations: 2
# dt: 0.42 s | Simulation Time: 453.6 s  of  840 s
#
# Step: Tension |   Increment: 1085 | Iterations: 2
# dt: 0.42 s | Simulation Time: 455.7 s  of  840 s
#
# Step: Tension |   Increment: 1090 | Iterations: 2
# dt: 0.42 s | Simulation Time: 457.8 s  of  840 s
#
# Step: Tension |   Increment: 1095 | Iterations: 2
# dt: 0.42 s | Simulation Time: 459.9 s  of  840 s
#
# Step: Tension |   Increment: 1100 | Iterations: 2
# dt: 0.42 s | Simulation Time: 462.0 s  of  840 s
#
# Step: Tension |   Increment: 1105 | Iterations: 2
# dt: 0.42 s | Simulation Time: 464.1 s  of  840 s
#
# Step: Tension |   Increment: 1110 | Iterations: 2
# dt: 0.42 s | Simulation Time: 466.2 s  of  840 s
#
# Step: Tension |   Increment: 1115 | Iterations: 2
# dt: 0.42 s | Simulation Time: 468.3 s  of  840 s
#
# Step: Tension |   Increment: 1120 | Iterations: 2
# dt: 0.42 s | Simulation Time: 470.4 s  of  840 s
#
# Step: Tension |   Increment: 1125 | Iterations: 2
# dt: 0.42 s | Simulation Time: 472.5 s  of  840 s
#
# Step: Tension |   Increment: 1130 | Iterations: 2
# dt: 0.42 s | Simulation Time: 474.6 s  of  840 s
#
# Step: Tension |   Increment: 1135 | Iterations: 2
# dt: 0.42 s | Simulation Time: 476.7 s  of  840 s
#
# Step: Tension |   Increment: 1140 | Iterations: 2
# dt: 0.42 s | Simulation Time: 478.8 s  of  840 s
#
# Step: Tension |   Increment: 1145 | Iterations: 2
# dt: 0.42 s | Simulation Time: 480.9 s  of  840 s
#
# Step: Tension |   Increment: 1150 | Iterations: 2
# dt: 0.42 s | Simulation Time: 483.0 s  of  840 s
#
# Step: Tension |   Increment: 1155 | Iterations: 2
# dt: 0.42 s | Simulation Time: 485.1 s  of  840 s
#
# Step: Tension |   Increment: 1160 | Iterations: 2
# dt: 0.42 s | Simulation Time: 487.2 s  of  840 s
#
# Step: Tension |   Increment: 1165 | Iterations: 2
# dt: 0.42 s | Simulation Time: 489.3 s  of  840 s
#
# Step: Tension |   Increment: 1170 | Iterations: 2
# dt: 0.42 s | Simulation Time: 491.4 s  of  840 s
#
# Step: Tension |   Increment: 1175 | Iterations: 2
# dt: 0.42 s | Simulation Time: 493.5 s  of  840 s
#
# Step: Tension |   Increment: 1180 | Iterations: 2
# dt: 0.42 s | Simulation Time: 495.6 s  of  840 s
#
# Step: Tension |   Increment: 1185 | Iterations: 2
# dt: 0.42 s | Simulation Time: 497.7 s  of  840 s
#
# Step: Tension |   Increment: 1190 | Iterations: 2
# dt: 0.42 s | Simulation Time: 499.8 s  of  840 s
#
# Step: Tension |   Increment: 1195 | Iterations: 2
# dt: 0.42 s | Simulation Time: 501.9 s  of  840 s
#
# Step: Tension |   Increment: 1200 | Iterations: 2
# dt: 0.42 s | Simulation Time: 504.0 s  of  840 s
#
# Step: Tension |   Increment: 1205 | Iterations: 2
# dt: 0.42 s | Simulation Time: 506.1 s  of  840 s
#
# Step: Tension |   Increment: 1210 | Iterations: 2
# dt: 0.42 s | Simulation Time: 508.2 s  of  840 s
#
# Step: Tension |   Increment: 1215 | Iterations: 2
# dt: 0.42 s | Simulation Time: 510.3 s  of  840 s
#
# Step: Tension |   Increment: 1220 | Iterations: 2
# dt: 0.42 s | Simulation Time: 512.4 s  of  840 s
#
# Step: Tension |   Increment: 1225 | Iterations: 2
# dt: 0.42 s | Simulation Time: 514.5 s  of  840 s
#
# Step: Tension |   Increment: 1230 | Iterations: 2
# dt: 0.42 s | Simulation Time: 516.6 s  of  840 s
#
# Step: Tension |   Increment: 1235 | Iterations: 2
# dt: 0.42 s | Simulation Time: 518.7 s  of  840 s
#
# Step: Tension |   Increment: 1240 | Iterations: 2
# dt: 0.42 s | Simulation Time: 520.8 s  of  840 s
#
# Step: Tension |   Increment: 1245 | Iterations: 2
# dt: 0.42 s | Simulation Time: 522.9 s  of  840 s
#
# Step: Tension |   Increment: 1250 | Iterations: 2
# dt: 0.42 s | Simulation Time: 525.0 s  of  840 s
#
# Step: Tension |   Increment: 1255 | Iterations: 4
# dt: 0.42 s | Simulation Time: 527.1 s  of  840 s
#
# Step: Tension |   Increment: 1260 | Iterations: 4
# dt: 0.42 s | Simulation Time: 529.2 s  of  840 s
#
# Step: Tension |   Increment: 1265 | Iterations: 3
# dt: 0.42 s | Simulation Time: 531.3 s  of  840 s
#
# Step: Tension |   Increment: 1270 | Iterations: 3
# dt: 0.42 s | Simulation Time: 533.4 s  of  840 s
#
# Step: Tension |   Increment: 1275 | Iterations: 3
# dt: 0.42 s | Simulation Time: 535.5 s  of  840 s
#
# Step: Tension |   Increment: 1280 | Iterations: 3
# dt: 0.42 s | Simulation Time: 537.6 s  of  840 s
#
# Step: Tension |   Increment: 1285 | Iterations: 3
# dt: 0.42 s | Simulation Time: 539.7 s  of  840 s
#
# Step: Tension |   Increment: 1290 | Iterations: 3
# dt: 0.42 s | Simulation Time: 541.8 s  of  840 s
#
# Step: Tension |   Increment: 1295 | Iterations: 3
# dt: 0.42 s | Simulation Time: 543.9 s  of  840 s
#
# Step: Tension |   Increment: 1300 | Iterations: 3
# dt: 0.42 s | Simulation Time: 546.0 s  of  840 s
#
# Step: Tension |   Increment: 1305 | Iterations: 3
# dt: 0.42 s | Simulation Time: 548.1 s  of  840 s
#
# Step: Tension |   Increment: 1310 | Iterations: 3
# dt: 0.42 s | Simulation Time: 550.2 s  of  840 s
#
# Step: Tension |   Increment: 1315 | Iterations: 3
# dt: 0.42 s | Simulation Time: 552.3 s  of  840 s
#
# Step: Tension |   Increment: 1320 | Iterations: 3
# dt: 0.42 s | Simulation Time: 554.4 s  of  840 s
#
# Step: Tension |   Increment: 1325 | Iterations: 3
# dt: 0.42 s | Simulation Time: 556.5 s  of  840 s
#
# Step: Tension |   Increment: 1330 | Iterations: 2
# dt: 0.42 s | Simulation Time: 558.6 s  of  840 s
#
# Step: Tension |   Increment: 1335 | Iterations: 2
# dt: 0.42 s | Simulation Time: 560.7 s  of  840 s
#
# Step: Tension |   Increment: 1340 | Iterations: 2
# dt: 0.42 s | Simulation Time: 562.8 s  of  840 s
#
# Step: Tension |   Increment: 1345 | Iterations: 2
# dt: 0.42 s | Simulation Time: 564.9 s  of  840 s
#
# Step: Tension |   Increment: 1350 | Iterations: 2
# dt: 0.42 s | Simulation Time: 567.0 s  of  840 s
#
# Step: Tension |   Increment: 1355 | Iterations: 2
# dt: 0.42 s | Simulation Time: 569.1 s  of  840 s
#
# Step: Tension |   Increment: 1360 | Iterations: 2
# dt: 0.42 s | Simulation Time: 571.2 s  of  840 s
#
# Step: Tension |   Increment: 1365 | Iterations: 2
# dt: 0.42 s | Simulation Time: 573.3 s  of  840 s
#
# Step: Tension |   Increment: 1370 | Iterations: 2
# dt: 0.42 s | Simulation Time: 575.4 s  of  840 s
#
# Step: Tension |   Increment: 1375 | Iterations: 2
# dt: 0.42 s | Simulation Time: 577.5 s  of  840 s
#
# Step: Tension |   Increment: 1380 | Iterations: 2
# dt: 0.42 s | Simulation Time: 579.6 s  of  840 s
#
# Step: Tension |   Increment: 1385 | Iterations: 2
# dt: 0.42 s | Simulation Time: 581.7 s  of  840 s
#
# Step: Tension |   Increment: 1390 | Iterations: 2
# dt: 0.42 s | Simulation Time: 583.8 s  of  840 s
#
# Step: Tension |   Increment: 1395 | Iterations: 2
# dt: 0.42 s | Simulation Time: 585.9 s  of  840 s
#
# Step: Tension |   Increment: 1400 | Iterations: 2
# dt: 0.42 s | Simulation Time: 588.0 s  of  840 s
#
# Step: Tension |   Increment: 1405 | Iterations: 2
# dt: 0.42 s | Simulation Time: 590.1 s  of  840 s
#
# Step: Tension |   Increment: 1410 | Iterations: 2
# dt: 0.42 s | Simulation Time: 592.2 s  of  840 s
#
# Step: Tension |   Increment: 1415 | Iterations: 2
# dt: 0.42 s | Simulation Time: 594.3 s  of  840 s
#
# Step: Tension |   Increment: 1420 | Iterations: 2
# dt: 0.42 s | Simulation Time: 596.4 s  of  840 s
#
# Step: Tension |   Increment: 1425 | Iterations: 2
# dt: 0.42 s | Simulation Time: 598.5 s  of  840 s
#
# Step: Tension |   Increment: 1430 | Iterations: 2
# dt: 0.42 s | Simulation Time: 600.6 s  of  840 s
#
# Step: Tension |   Increment: 1435 | Iterations: 2
# dt: 0.42 s | Simulation Time: 602.7 s  of  840 s
#
# Step: Tension |   Increment: 1440 | Iterations: 2
# dt: 0.42 s | Simulation Time: 604.8 s  of  840 s
#
# Step: Tension |   Increment: 1445 | Iterations: 2
# dt: 0.42 s | Simulation Time: 606.9 s  of  840 s
#
# Step: Tension |   Increment: 1450 | Iterations: 2
# dt: 0.42 s | Simulation Time: 609.0 s  of  840 s
#
# Step: Tension |   Increment: 1455 | Iterations: 2
# dt: 0.42 s | Simulation Time: 611.1 s  of  840 s
#
# Step: Tension |   Increment: 1460 | Iterations: 2
# dt: 0.42 s | Simulation Time: 613.2 s  of  840 s
#
# Step: Tension |   Increment: 1465 | Iterations: 2
# dt: 0.42 s | Simulation Time: 615.3 s  of  840 s
#
# Step: Tension |   Increment: 1470 | Iterations: 2
# dt: 0.42 s | Simulation Time: 617.4 s  of  840 s
#
# Step: Tension |   Increment: 1475 | Iterations: 2
# dt: 0.42 s | Simulation Time: 619.5 s  of  840 s
#
# Step: Tension |   Increment: 1480 | Iterations: 2
# dt: 0.42 s | Simulation Time: 621.6 s  of  840 s
#
# Step: Tension |   Increment: 1485 | Iterations: 2
# dt: 0.42 s | Simulation Time: 623.7 s  of  840 s
#
# Step: Tension |   Increment: 1490 | Iterations: 2
# dt: 0.42 s | Simulation Time: 625.8 s  of  840 s
#
# Step: Tension |   Increment: 1495 | Iterations: 2
# dt: 0.42 s | Simulation Time: 627.9 s  of  840 s
#
# Step: Tension |   Increment: 1500 | Iterations: 2
# dt: 0.42 s | Simulation Time: 630.0 s  of  840 s
#
# Step: Tension |   Increment: 1505 | Iterations: 4
# dt: 0.42 s | Simulation Time: 632.1 s  of  840 s
#
# Step: Tension |   Increment: 1510 | Iterations: 4
# dt: 0.42 s | Simulation Time: 634.2 s  of  840 s
#
# Step: Tension |   Increment: 1515 | Iterations: 3
# dt: 0.42 s | Simulation Time: 636.3 s  of  840 s
#
# Step: Tension |   Increment: 1520 | Iterations: 3
# dt: 0.42 s | Simulation Time: 638.4 s  of  840 s
#
# Step: Tension |   Increment: 1525 | Iterations: 3
# dt: 0.42 s | Simulation Time: 640.5 s  of  840 s
#
# Step: Tension |   Increment: 1530 | Iterations: 3
# dt: 0.42 s | Simulation Time: 642.6 s  of  840 s
#
# Step: Tension |   Increment: 1535 | Iterations: 3
# dt: 0.42 s | Simulation Time: 644.7 s  of  840 s
#
# Step: Tension |   Increment: 1540 | Iterations: 3
# dt: 0.42 s | Simulation Time: 646.8 s  of  840 s
#
# Step: Tension |   Increment: 1545 | Iterations: 3
# dt: 0.42 s | Simulation Time: 648.9 s  of  840 s
#
# Step: Tension |   Increment: 1550 | Iterations: 3
# dt: 0.42 s | Simulation Time: 651.0 s  of  840 s
#
# Step: Tension |   Increment: 1555 | Iterations: 3
# dt: 0.42 s | Simulation Time: 653.1 s  of  840 s
#
# Step: Tension |   Increment: 1560 | Iterations: 3
# dt: 0.42 s | Simulation Time: 655.2 s  of  840 s
#
# Step: Tension |   Increment: 1565 | Iterations: 3
# dt: 0.42 s | Simulation Time: 657.3 s  of  840 s
#
# Step: Tension |   Increment: 1570 | Iterations: 3
# dt: 0.42 s | Simulation Time: 659.4 s  of  840 s
#
# Step: Tension |   Increment: 1575 | Iterations: 3
# dt: 0.42 s | Simulation Time: 661.5 s  of  840 s
#
# Step: Tension |   Increment: 1580 | Iterations: 3
# dt: 0.42 s | Simulation Time: 663.6 s  of  840 s
#
# Step: Tension |   Increment: 1585 | Iterations: 3
# dt: 0.42 s | Simulation Time: 665.7 s  of  840 s
#
# Step: Tension |   Increment: 1590 | Iterations: 2
# dt: 0.42 s | Simulation Time: 667.8 s  of  840 s
#
# Step: Tension |   Increment: 1595 | Iterations: 2
# dt: 0.42 s | Simulation Time: 669.9 s  of  840 s
#
# Step: Tension |   Increment: 1600 | Iterations: 2
# dt: 0.42 s | Simulation Time: 672.0 s  of  840 s
#
# Step: Tension |   Increment: 1605 | Iterations: 2
# dt: 0.42 s | Simulation Time: 674.1 s  of  840 s
#
# Step: Tension |   Increment: 1610 | Iterations: 2
# dt: 0.42 s | Simulation Time: 676.2 s  of  840 s
#
# Step: Tension |   Increment: 1615 | Iterations: 2
# dt: 0.42 s | Simulation Time: 678.3 s  of  840 s
#
# Step: Tension |   Increment: 1620 | Iterations: 2
# dt: 0.42 s | Simulation Time: 680.4 s  of  840 s
#
# Step: Tension |   Increment: 1625 | Iterations: 2
# dt: 0.42 s | Simulation Time: 682.5 s  of  840 s
#
# Step: Tension |   Increment: 1630 | Iterations: 2
# dt: 0.42 s | Simulation Time: 684.6 s  of  840 s
#
# Step: Tension |   Increment: 1635 | Iterations: 2
# dt: 0.42 s | Simulation Time: 686.7 s  of  840 s
#
# Step: Tension |   Increment: 1640 | Iterations: 2
# dt: 0.42 s | Simulation Time: 688.8 s  of  840 s
#
# Step: Tension |   Increment: 1645 | Iterations: 2
# dt: 0.42 s | Simulation Time: 690.9 s  of  840 s
#
# Step: Tension |   Increment: 1650 | Iterations: 2
# dt: 0.42 s | Simulation Time: 693.0 s  of  840 s
#
# Step: Tension |   Increment: 1655 | Iterations: 2
# dt: 0.42 s | Simulation Time: 695.1 s  of  840 s
#
# Step: Tension |   Increment: 1660 | Iterations: 2
# dt: 0.42 s | Simulation Time: 697.2 s  of  840 s
#
# Step: Tension |   Increment: 1665 | Iterations: 2
# dt: 0.42 s | Simulation Time: 699.3 s  of  840 s
#
# Step: Tension |   Increment: 1670 | Iterations: 2
# dt: 0.42 s | Simulation Time: 701.4 s  of  840 s
#
# Step: Tension |   Increment: 1675 | Iterations: 2
# dt: 0.42 s | Simulation Time: 703.5 s  of  840 s
#
# Step: Tension |   Increment: 1680 | Iterations: 2
# dt: 0.42 s | Simulation Time: 705.6 s  of  840 s
#
# Step: Tension |   Increment: 1685 | Iterations: 2
# dt: 0.42 s | Simulation Time: 707.7 s  of  840 s
#
# Step: Tension |   Increment: 1690 | Iterations: 2
# dt: 0.42 s | Simulation Time: 709.8 s  of  840 s
#
# Step: Tension |   Increment: 1695 | Iterations: 2
# dt: 0.42 s | Simulation Time: 711.9 s  of  840 s
#
# Step: Tension |   Increment: 1700 | Iterations: 2
# dt: 0.42 s | Simulation Time: 714.0 s  of  840 s
#
# Step: Tension |   Increment: 1705 | Iterations: 2
# dt: 0.42 s | Simulation Time: 716.1 s  of  840 s
#
# Step: Tension |   Increment: 1710 | Iterations: 2
# dt: 0.42 s | Simulation Time: 718.2 s  of  840 s
#
# Step: Tension |   Increment: 1715 | Iterations: 2
# dt: 0.42 s | Simulation Time: 720.3 s  of  840 s
#
# Step: Tension |   Increment: 1720 | Iterations: 2
# dt: 0.42 s | Simulation Time: 722.4 s  of  840 s
#
# Step: Tension |   Increment: 1725 | Iterations: 2
# dt: 0.42 s | Simulation Time: 724.5 s  of  840 s
#
# Step: Tension |   Increment: 1730 | Iterations: 2
# dt: 0.42 s | Simulation Time: 726.6 s  of  840 s
#
# Step: Tension |   Increment: 1735 | Iterations: 2
# dt: 0.42 s | Simulation Time: 728.7 s  of  840 s
#
# Step: Tension |   Increment: 1740 | Iterations: 2
# dt: 0.42 s | Simulation Time: 730.8 s  of  840 s
#
# Step: Tension |   Increment: 1745 | Iterations: 2
# dt: 0.42 s | Simulation Time: 732.9 s  of  840 s
#
# Step: Tension |   Increment: 1750 | Iterations: 2
# dt: 0.42 s | Simulation Time: 735.0 s  of  840 s
#
# Step: Tension |   Increment: 1755 | Iterations: 4
# dt: 0.42 s | Simulation Time: 737.1 s  of  840 s
#
# Step: Tension |   Increment: 1760 | Iterations: 4
# dt: 0.42 s | Simulation Time: 739.2 s  of  840 s
#
# Step: Tension |   Increment: 1765 | Iterations: 3
# dt: 0.42 s | Simulation Time: 741.3 s  of  840 s
#
# Step: Tension |   Increment: 1770 | Iterations: 3
# dt: 0.42 s | Simulation Time: 743.4 s  of  840 s
#
# Step: Tension |   Increment: 1775 | Iterations: 3
# dt: 0.42 s | Simulation Time: 745.5 s  of  840 s
#
# Step: Tension |   Increment: 1780 | Iterations: 3
# dt: 0.42 s | Simulation Time: 747.6 s  of  840 s
#
# Step: Tension |   Increment: 1785 | Iterations: 3
# dt: 0.42 s | Simulation Time: 749.7 s  of  840 s
#
# Step: Tension |   Increment: 1790 | Iterations: 3
# dt: 0.42 s | Simulation Time: 751.8 s  of  840 s
#
# Step: Tension |   Increment: 1795 | Iterations: 3
# dt: 0.42 s | Simulation Time: 753.9 s  of  840 s
#
# Step: Tension |   Increment: 1800 | Iterations: 3
# dt: 0.42 s | Simulation Time: 756.0 s  of  840 s
#
# Step: Tension |   Increment: 1805 | Iterations: 3
# dt: 0.42 s | Simulation Time: 758.1 s  of  840 s
#
# Step: Tension |   Increment: 1810 | Iterations: 3
# dt: 0.42 s | Simulation Time: 760.2 s  of  840 s
#
# Step: Tension |   Increment: 1815 | Iterations: 3
# dt: 0.42 s | Simulation Time: 762.3 s  of  840 s
#
# Step: Tension |   Increment: 1820 | Iterations: 3
# dt: 0.42 s | Simulation Time: 764.4 s  of  840 s
#
# Step: Tension |   Increment: 1825 | Iterations: 3
# dt: 0.42 s | Simulation Time: 766.5 s  of  840 s
#
# Step: Tension |   Increment: 1830 | Iterations: 3
# dt: 0.42 s | Simulation Time: 768.6 s  of  840 s
#
# Step: Tension |   Increment: 1835 | Iterations: 3
# dt: 0.42 s | Simulation Time: 770.7 s  of  840 s
#
# Step: Tension |   Increment: 1840 | Iterations: 3
# dt: 0.42 s | Simulation Time: 772.8 s  of  840 s
#
# Step: Tension |   Increment: 1845 | Iterations: 3
# dt: 0.42 s | Simulation Time: 774.9 s  of  840 s
#
# Step: Tension |   Increment: 1850 | Iterations: 2
# dt: 0.42 s | Simulation Time: 777.0 s  of  840 s
#
# Step: Tension |   Increment: 1855 | Iterations: 2
# dt: 0.42 s | Simulation Time: 779.1 s  of  840 s
#
# Step: Tension |   Increment: 1860 | Iterations: 2
# dt: 0.42 s | Simulation Time: 781.2 s  of  840 s
#
# Step: Tension |   Increment: 1865 | Iterations: 2
# dt: 0.42 s | Simulation Time: 783.3 s  of  840 s
#
# Step: Tension |   Increment: 1870 | Iterations: 2
# dt: 0.42 s | Simulation Time: 785.4 s  of  840 s
#
# Step: Tension |   Increment: 1875 | Iterations: 2
# dt: 0.42 s | Simulation Time: 787.5 s  of  840 s
#
# Step: Tension |   Increment: 1880 | Iterations: 2
# dt: 0.42 s | Simulation Time: 789.6 s  of  840 s
#
# Step: Tension |   Increment: 1885 | Iterations: 2
# dt: 0.42 s | Simulation Time: 791.7 s  of  840 s
#
# Step: Tension |   Increment: 1890 | Iterations: 2
# dt: 0.42 s | Simulation Time: 793.8 s  of  840 s
#
# Step: Tension |   Increment: 1895 | Iterations: 2
# dt: 0.42 s | Simulation Time: 795.9 s  of  840 s
#
# Step: Tension |   Increment: 1900 | Iterations: 2
# dt: 0.42 s | Simulation Time: 798.0 s  of  840 s
#
# Step: Tension |   Increment: 1905 | Iterations: 2
# dt: 0.42 s | Simulation Time: 800.1 s  of  840 s
#
# Step: Tension |   Increment: 1910 | Iterations: 2
# dt: 0.42 s | Simulation Time: 802.2 s  of  840 s
#
# Step: Tension |   Increment: 1915 | Iterations: 2
# dt: 0.42 s | Simulation Time: 804.3 s  of  840 s
#
# Step: Tension |   Increment: 1920 | Iterations: 2
# dt: 0.42 s | Simulation Time: 806.4 s  of  840 s
#
# Step: Tension |   Increment: 1925 | Iterations: 2
# dt: 0.42 s | Simulation Time: 808.5 s  of  840 s
#
# Step: Tension |   Increment: 1930 | Iterations: 2
# dt: 0.42 s | Simulation Time: 810.6 s  of  840 s
#
# Step: Tension |   Increment: 1935 | Iterations: 2
# dt: 0.42 s | Simulation Time: 812.7 s  of  840 s
#
# Step: Tension |   Increment: 1940 | Iterations: 2
# dt: 0.42 s | Simulation Time: 814.8 s  of  840 s
#
# Step: Tension |   Increment: 1945 | Iterations: 2
# dt: 0.42 s | Simulation Time: 816.9 s  of  840 s
#
# Step: Tension |   Increment: 1950 | Iterations: 2
# dt: 0.42 s | Simulation Time: 819.0 s  of  840 s
#
# Step: Tension |   Increment: 1955 | Iterations: 2
# dt: 0.42 s | Simulation Time: 821.1 s  of  840 s
#
# Step: Tension |   Increment: 1960 | Iterations: 2
# dt: 0.42 s | Simulation Time: 823.2 s  of  840 s
#
# Step: Tension |   Increment: 1965 | Iterations: 2
# dt: 0.42 s | Simulation Time: 825.3 s  of  840 s
#
# Step: Tension |   Increment: 1970 | Iterations: 2
# dt: 0.42 s | Simulation Time: 827.4 s  of  840 s
#
# Step: Tension |   Increment: 1975 | Iterations: 2
# dt: 0.42 s | Simulation Time: 829.5 s  of  840 s
#
# Step: Tension |   Increment: 1980 | Iterations: 2
# dt: 0.42 s | Simulation Time: 831.6 s  of  840 s
#
# Step: Tension |   Increment: 1985 | Iterations: 2
# dt: 0.42 s | Simulation Time: 833.7 s  of  840 s
#
# Step: Tension |   Increment: 1990 | Iterations: 2
# dt: 0.42 s | Simulation Time: 835.8 s  of  840 s
#
# Step: Tension |   Increment: 1995 | Iterations: 2
# dt: 0.42 s | Simulation Time: 837.9 s  of  840 s
#
# Step: Tension |   Increment: 2000 | Iterations: 2
# dt: 0.42 s | Simulation Time: 840.0 s  of  840 s
#
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:00:18.593870
# ------------------------------------------

# %% [markdown]
# # Plot results

# %%
# Set plot font to size 14
font = {'size'   : 14}
plt.rc('font', **font)

# Get array of default plot colors
prop_cycle = plt.rcParams['axes.prop_cycle']
colors     = prop_cycle.by_key()['color']

# Only plot as far as we have time history data
ind = np.argmax(timeHist0) +1

eq_data = np.genfromtxt('results/eq_stretch_stress_data.csv', delimiter=',')
ind2 = np.where(eq_data[0,:] >= 2.0)[0][0] 

fig = plt.figure() 
ax=fig.gca()  
plt.plot(timeHist1[0:ind]/length + 1, timeHist2[0:ind]/(length*length), c=colors[3], linewidth=2.0)
plt.plot(eq_data[0,0:ind2],  eq_data[1,0:ind2], linewidth=1.0, color='k', linestyle="--", label=r"Equilibrium response")
#-------------------------------------------------------------
# ax.set_xlim(1,2.1)
# ax.set_ylim(0, 400)
#plt.axis('tight')
plt.grid(linestyle="--", linewidth=0.5, color='b')
ax.set_xlabel(r'$\lambda$')
ax.set_ylabel(r'$T_{R \, 22},$ kPa')
ax.set_ylim([-30, 40])
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
# plt.show()


plt.legend()

fig = plt.gcf()
fig.set_size_inches(7,5)
plt.tight_layout()
plt.savefig("results/VHB_stretch_hold_stress.png", dpi=600)

# %%
# Set plot font to size 14
font = {'size'   : 14}
plt.rc('font', **font)

# Get array of default plot colors
prop_cycle = plt.rcParams['axes.prop_cycle']
colors     = prop_cycle.by_key()['color']

# Only plot as far as we have time history data
ind = np.argmax(timeHist0) + 1

fig, (ax1, ax2) = plt.subplots(2,1, sharex='col')

ax2.plot(timeHist0[0:ind], timeHist2[0:ind]/(length*length), c=colors[3], linewidth=2.0)
ax2.grid(linestyle="--", linewidth=0.5, color='b')
ax2.set_ylabel(r'$T_{R \, 22},$ kPa')
ax2.set_xlabel('Time (s)')
ax2.set_ylim(-25, 40)
ax2.set_xlim(0, 900)
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax2.xaxis.set_minor_locator(AutoMinorLocator())
ax2.yaxis.set_minor_locator(AutoMinorLocator())

ax1.plot(timeHist0[0:ind], timeHist1[0:ind]/length+1, c=colors[0], linewidth=2.0)
ax1.grid(linestyle="--", linewidth=0.5, color='b')
ax1.set_ylabel('$\lambda$')
ax1.set_ylim(0.8, 2.4)
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax1.xaxis.set_minor_locator(AutoMinorLocator())
ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.show()

fig = plt.gcf()
fig.set_size_inches(8,5)
plt.tight_layout()
plt.savefig("results/VHB_stretch_hold_time.png", dpi=600)
